# %%
from PIL import Image
import numpy as np
#data = np.load('imgs.npy')
data = np.load("Face_Images/x_test.npy") / 255

data.shape
# Out:
# (642, 96, 96, 1)

# %%
from matplotlib import pyplot as plt

for i in range(3):
  plt.imshow(data[i], cmap='gray')
  plt.show(3)
  #
